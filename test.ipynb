# %% [markdown]
# <a href="https://colab.research.google.com/github/filfish2007-cav/ITStep-AI/blob/superwised_learning/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = 'John'
age = 30

print(name,age)
# Out:
# John 30

# %%
print(age)
# Out:
# 32

# %%
age += 1

# %%
print(age)
# Out:
# 32
